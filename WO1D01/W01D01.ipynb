# %%
print('hello world')
# Out:
# hello world

# %%
print('Hi Satya')
# Out:
# Hi Satya

# %%
Input/output operations

# %%
age = input('Hi Tell me your age')
# Out:
# Hi Tell me your age 2

# %%
print(age)
# Out:
# 2

# %%
name = input('Hi What is your name')
# Out:
# Hi What is your name Rohan

# %%
print(name)
# Out:
# Rohan

# %%
Data Types ?

Data Structures?

kind of data

Bottle, Plate

data/thing is milk ?

container? what can be stored in that container.

# %%
x = "5.5"
